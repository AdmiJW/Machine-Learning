# %% [markdown]
# # Machine Learning with Tensorflow

# %% [markdown]
# <br>
#
# ---
#
# ## 1.0 - Ensure Tensorflow is Installed
#
# ---
# <br>
#
# Run the below `pip` command. If you don't see `tensorflow` anywhere, install it first through the second cell

# %%
# %%cmd
# pip list
# Out:
# Microsoft Windows [Version 10.0.19042.1110]
# (c) Microsoft Corporation. All rights reserved.
#
# (venv) D:\My Desktop\Programming\Projects\MachineLearning>pip list
# Package                 Version
# ----------------------- -------------------
# absl-py                 0.13.0
# argon2-cffi             20.1.0
# astunparse              1.6.3
# async-generator         1.10
# attrs                   21.2.0
# backcall                0.2.0
# bleach                  3.3.1
# cachetools              4.2.2
# certifi                 2021.5.30
# cffi                    1.14.6
# charset-normalizer      2.0.4
# colorama                0.4.4
# debugpy                 1.4.1
# decorator               5.0.9
# defusedxml              0.7.1
# entrypoints             0.3
# flatbuffers             1.12
# gast                    0.4.0
# google-auth             1.34.0
# google-auth-oauthlib    0.4.5
# google-pasta            0.2.0
# grpcio                  1.34.1
# h5py                    3.1.0
# ...

# %%
# %%cmd
# pip install --upgrade tensorflow
# Out:
# Microsoft Windows [Version 10.0.19042.1110]
# (c) Microsoft Corporation. All rights reserved.
#
# (venv) D:\My Desktop\Programming\Projects\MachineLearning>pip install --upgrade tensorflow
# ...
#   Using cached tensorflow-2.5.0-cp39-cp39-win_amd64.whl (422.6 MB)
# ...
#   Using cached wrapt-1.12.1-cp39-cp39-win_amd64.whl
# ...
#   Using cached grpcio-1.34.1-cp39-cp39-win_amd64.whl (2.9 MB)
# ...
#   Using cached h5py-3.1.0-cp39-cp39-win_amd64.whl (2.7 MB)
# ...
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# ...
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# ...
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# ...
#   Using cached protobuf-3.17.3-cp39-cp39-win_amd64.whl (909 kB)
# ...
#   Using cached Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
# ...
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# ...
#   Using cached absl_py-0.13.0-py3-none-any.whl (132 kB)
# ...
#   Using cached six-1.15.0-py2.py3-none-any.whl (10 kB)
# ...

# %% [markdown]
# <br>
#
# ---
#
# ## 2.0 - Tensorflow
#
# ---
# <br>

# %%
import tensorflow as tf

# %%
# If this prints a Tensor object, it means tensorflow is installed correctly in your machine
print(tf.reduce_sum(tf.random.normal([1000, 1000])))
# Out:
# tf.Tensor(1.0497742, shape=(), dtype=float32)
